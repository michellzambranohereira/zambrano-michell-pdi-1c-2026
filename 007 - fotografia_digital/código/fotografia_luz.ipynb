# %%
import cv2
import matplotlib.pyplot as plt

#Leer imagen
imagen = cv2.imread("C:\\Users\\usuario\\zambrano-michell-pdi-1c-2026\\007 - fotografia_digital\\imagenes\\originales\\imagen_rio_horizontal.jpeg")

#Convertir de BGR a RGB
imagen_rgb = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)

#Mostrar dentro del notebook
plt.imshow(imagen_rgb)
plt.axis("off")
plt.title("Imagen")
plt.show()

# %% [markdown]
# ## Preguntas guía
# ¿La luz revela o esconde?
# La luz oculta parcialmente algunos elementos al generar siluetas y zonas de sombra, mientras destaca reflejos y bordes iluminados.
#
# ¿Genera textura?
# Sí. La iluminación lateral resalta la textura del suelo, las barandas y el movimiento del agua.
#
# ¿Construye atmósfera?
# Sí. La luz cálida del atardecer genera una atmósfera tranquila y cálida.
#
# ¿Cómo cambia el volumen?
# Las sombras proyectadas y el contraste de iluminación aportan sensación de profundidad y volumen en la escena.
